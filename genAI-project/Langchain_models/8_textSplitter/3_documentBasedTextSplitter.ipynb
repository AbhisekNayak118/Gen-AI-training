# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

# %%
sentences = """ 
This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. This is a sentence. This is another sentence. This is yet another sentence. 
"""

# %%
splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=200, 
    chunk_overlap=0,
)

# %%
chunks = splitter.split_text(sentences)
# res = splitter.spl
print(len(chunks))
print(chunks)
# Out:
# 3
# ['# Project Name: Smart Student Tracker\n\nA simple Python-based project to manage and track student data, including their grades, age, and academic status.\n\n\n## Features', '- Add new students with relevant info\n- View student details\n- Check if a student is passing\n- Easily extendable class-based design\n\n\n## 🛠 Tech Stack\n\n- Python 3.10+\n- No external dependencies', '## Getting Started\n\n1. Clone the repo  \n   ```bash\n   git clone https://github.com/your-username/student-tracker.git']
