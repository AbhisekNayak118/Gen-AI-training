# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv

import os
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    model = "MiniMaxAI/MiniMax-M2.5",
    task = "text-generation",
    huggingfacehub_api_token= os.getenv("HUGGINGFACEHUB_API_TOKEN")
)

# %%
model = ChatHuggingFace(llm=llm)

# %%
prompt1 = PromptTemplate(
    template='Answer the following question \n {question} from the following text - \n {text}',
    input_variables=['question','text']
)

# %%
parser = StrOutputParser()

# %%
url = 'https://www.flipkart.com/apple-macbook-air-m2-16-gb-256-gb-ssd-macos-sequoia-mc7x4hn-a/p/itmdc5308fa78421'

# %%
wbLoader = WebBaseLoader(url) 
# List of url is possble too, different object for differet url

# %%
docs = wbLoader.load()

# %%
chain = model | prompt1 | parser

# %%
final_res = chain.invoke({
    "role": "What is the product that we are talking about?",
    "context": docs[0].page_content
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/messages/utils.py:713, in _convert_to_message(message)
#     712 try:
# --> 713     msg_type = msg_kwargs.pop("role")
#     714 except KeyError:
#
# KeyError: 'role'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/messages/utils.py:715, in _convert_to_message(message)
#     714 except KeyError:
# --> 715     msg_type = msg_kwargs.pop("type")
#     716 # None msg content is not allowed
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 final_res = chain.invoke([
#       2     {
#       3         'question':'What is the prodcut that we are talking about?',
#       4         'text':docs[0].page_content
#       5     }
#       6 ])
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/runnables/base.py:3155, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3153 with set_config_context(config) as context:
#    3154     if i == 0:
# -> 3155         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156     else:
#    3157         input_ = context.run(step.invoke, input_, config)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:455, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
#     454             self.generate_prompt(
# --> 455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:433, in BaseChatModel._convert_input(self, model_input)
#     431     return StringPromptValue(text=model_input)
#     432 if isinstance(model_input, Sequence):
# --> 433     return ChatPromptValue(messages=convert_to_messages(model_input))
#     434 msg = (
#     435     f"Invalid input type {type(model_input)}. "
#     436     "Must be a PromptValue, str, or list of BaseMessages."
#     437 )
#     438 raise ValueError(msg)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/messages/utils.py:752, in convert_to_messages(messages)
#     750 if isinstance(messages, PromptValue):
#     751     return messages.to_messages()
# --> 752 return [_convert_to_message(m) for m in messages]
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/messages/utils.py:723, in _convert_to_message(message)
#     719         msg = f"Message dict must contain 'role' and 'content' keys, got {message}"
#     720         msg = create_message(
#     721             message=msg, error_code=ErrorCode.MESSAGE_COERCION_FAILURE
#     722         )
# --> 723         raise ValueError(msg) from e
#     724     message_ = _create_message_from_message_type(
#     725         msg_type, msg_content, **msg_kwargs
#     726     )
#     727 else:
#
# ValueError: Message dict must contain 'role' and 'content' keys, got {'question': 'What is the prodcut that we are talking about?', 'text': 'Flipkart reCAPTCHAAre you a human?Confirming...'}
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/MESSAGE_COERCION_FAILURE

# %%
print(final_res)
