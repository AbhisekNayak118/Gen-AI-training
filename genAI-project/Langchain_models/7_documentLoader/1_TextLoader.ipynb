# %%
from langchain_community.document_loaders import TextLoader
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

from dotenv import load_dotenv
import os       

load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    model = "MiniMaxAI/MiniMax-M2.5",
    task = "text-generation",
    huggingfacehub_api_token= os.getenv("HUGGINGFACEHUB_API_TOKEN")
)

# %%
model = ChatHuggingFace(llm = llm)

# %%
parser = StrOutputParser()

# %%
tLoader = TextLoader("Hell.txt", encoding="utf-8")

# %%
docs = tLoader.load()

# %%
# print(type(docs))
# print(docs[0].page_content)

# print("----------------------------------------------------------------------")
# print(docs[0].metadata)

# %%
prompt1 = PromptTemplate(
    template = 'Write a detailed summary on {topic}',
    input_variables = ['topic']
)

# %%
chain = prompt1 | model | parser

# %%
print(chain.invoke({"topic": docs[0].page_content}))
# Out:
# # Detailed Summary of "Letters from Hell" (Vol. I)
#
# ## Overview and Literary Context
#
# "Letters from Hell" is an 1866 religious allegorical novel written under the pseudonym M. Bowel. The work presents itself as a series of letters written from the underworld by a damned soul to his friends and family on earth. The narrative combines vivid depictions of hellish torments with moralistic commentary and autobiographical confessions from the protagonist, providing a window into his life of sin that led to his damnation. The book serves both as a warning to the living and as a meditation on the consequences of a life lived without faith in God.
#
# The narrative is framed with a preface and postscript by an unnamed editor who claims to have received these letters and decided to publish them as a warning to others. The editor expresses hope that the letters might touch hearts and lead readers to repentance, while acknowledging that for some, the warnings will come too late.
#
# ## The Narrative Frame
#
# The novel opens with an elaborate setup about how the letters came into the narrator's possession. The editor expresses hesitation about publishing such material, knowing it will cause restlessness and pain to many. However, he is motivated by the hope that some hearts might be touched and brought to inquire: "Ah! what shall we do?" The answer provided is clear: "Repent, and believe the Gospel." This sets the tone for the entire
