# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence, RunnableParallel

from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template = 'Generate a tweet about {topic}',
    input_variables = ['topic']
)

# %%
prompt2 = PromptTemplate(
    template = 'Generate a LinkedIN post about {topic}',
    input_variables = ['topic']
)

# %%
llm = HuggingFaceEndpoint(
    model="MiniMaxAI/MiniMax-M2.5",
    task = "text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_API_TOKEN")
)

# %%
model = ChatHuggingFace(llm = llm)

# %%
parser = StrOutputParser()

# %%
parallel_chains = RunnableParallel({
    "tweet": RunnableSequence(prompt1, model, parser),
    "linkedin_post": RunnableSequence(prompt2, model, parser)
})

# %%
print(parallel_chains.invoke({"topic": "Artificial Intelligence"}))
# Out:
# {'tweet': "🤖 AI is reshaping our world—enhancing creativity, automating tasks, and solving complex problems faster than ever. The future is smarter, and it's just beginning! 🌍✨ #AI #FutureTech #Innovation", 'linkedin_post': "Here's a LinkedIn post about Artificial Intelligence:\n\n---\n\n**💡 AI Isn't Replacing Humans. It's Powering Them.**\n\nAfter spending years in the AI space, here's what I've learned:\n\nThe biggest misconception about Artificial Intelligence?\n\nThat it's here to replace us.\n\nThe truth? AI is here to **amplify** us.\n\nHere's what AI actually does in the workplace:\n\n✅ Automates repetitive tasks → giving us time for creative work\n✅ Analyzes massive data in seconds → helping us make better decisions\n✅ Handles customer queries 24/7 → so humans can solve complex problems\n✅ Identifies patterns we'd miss → surfacing insights we never knew existed\n\nThe companies winning with AI aren't the ones replacing people.\nThey're the ones using AI to make their people **more powerful**.\n\nThe future isn't human vs. AI.\nIt's human **with** AI.\n\nWhat's your take? 👇\n\nAre you using AI in your work? What's been your experience?\n\n#ArtificialIntelligence #AI #FutureOfWork #Tech #Innovation #Leadership\n\n---\n\n**Tips for engagement:**\n\n- Personalize it with your own experience or results\n- Add a relevant visual (infographic, photo, or video still)\n- Post during peak LinkedIn hours (Tue-Thu, 8-10am or 12-1pm)\n- Respond to comments early to boost algorithm visibility\n\nWould you like me to adjust the tone, focus on a specific AI topic, or make it shorter/longer?"}
