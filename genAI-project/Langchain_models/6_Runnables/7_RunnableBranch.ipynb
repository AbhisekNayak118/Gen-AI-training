# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence, RunnableParallel, RunnablePassthrough, RunnableLambda, RunnableBranch

from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template = 'Write a detailed report on {topic}',
    input_variables = ['topic']
)

# %%
llm = HuggingFaceEndpoint(
    model="MiniMaxAI/MiniMax-M2.5",
    task = "text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_API_TOKEN")
)

# %%
model = ChatHuggingFace(llm = llm)

# %%
parser = StrOutputParser()

# %%
report_gen_chain = RunnableSequence(prompt1, model, parser)

# %%
prompt2 = PromptTemplate(
    template = 'Generate a tweet about {topic}', 
    input_variables = ['topic']
)

# %%
branch_chain = RunnableBranch(
    (lambda x: len(x.split())> 300 ,RunnableSequence(prompt2, model, parser)),
    RunnablePassthrough()
)

# %%
final_chain = RunnableSequence(report_gen_chain, branch_chain)

# %%
result = final_chain.invoke({'topic': 'America VS India'})

# %%
print(result)
# Out:
# # America vs. India: A Comprehensive Comparative Report
#
# ---
#
# ## Executive Summary
#
# The United States and India represent two of the world's most influential democracies, each playing pivotal roles in global economics, politics, and culture. While the United States emerged as the world's dominant economic and military power in the 20th century, India has grown into an emerging economic powerhouse with the world's largest population and a rapidly advancing technological sector. This report examines these two nations across multiple dimensions to provide a comprehensive understanding of their similarities, differences, and respective positions in the global landscape.
#
# ---
#
# ## 1. Introduction
#
# The comparison between the United States and India offers fascinating insights into two distinct yet interconnected paths of national development. Both countries share the heritage of British colonialism, operate as federal democratic republics, and maintain constitutions that guarantee fundamental rights to their citizens. However, their historical trajectories, demographic compositions, economic models, and strategic priorities differ substantially.
#
# As of 2024, the United States remains the world's largest economy by nominal GDP, while India has emerged as the fifth-largest economy and is projected to become the third-largest by the late 2020s. The bilateral relationship between these two nations has evolved from Cold War era tensions to a strategic partnership focused on defense cooperation, trade, and technology sharing.
#
# ---
#
# ## 2. Geographic and Demographic Comparison
#
# ### 2.1 Land Area and Geography
#
# | Attribute | United States | India |
# |-----------|---------------|-------|
# | Total Area | 9.83 million km² | 3.29 million km² |
# | World Ranking | 3rd | 7th |
# | Arable Land | ~17% | ~52% |
# | Coastline | 195,000 km | 7,500 km |
#
# The United States possesses roughly three times the land area of India but with a

# %% [markdown]
# LCEL: Replacing the RunnableSequnce() runnable, it was induced that using '|' is much more easier, as RunnableSequence() is widely used.
