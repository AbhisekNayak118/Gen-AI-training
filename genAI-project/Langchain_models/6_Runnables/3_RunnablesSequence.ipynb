# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence

from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
prompt = PromptTemplate(
    template = "Write a joke about {topic}",
    input_variables = ["topic"]
)

# %%
prompt2 = PromptTemplate(
    template = "Explain the joke on {text}",
    input_variables = ["text"]
)

# %%
llm = HuggingFaceEndpoint(
    model="MiniMaxAI/MiniMax-M2.5",
    task = "text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_API_TOKEN")
)
# from langchain_
# model = ChatOpenAI()

# %%
model = ChatHuggingFace(llm = llm)

# %%
parser = StrOutputParser()

# %%
chain = RunnableSequence(prompt, model, parser, prompt2, model, parser)

# %%
print(chain.invoke({'topic': "AI"}))
# Out:
# This is a pun-based joke that plays on double meanings:
#
# **"Too many layers"**
# - In AI/ML: Neural networks have multiple "layers" (input, hidden, output). More layers = deeper neural networks.
# - In therapy speak: People are often described as having "layers" of emotional complexity or defense mechanisms.
#
# **"Couldn't process its feelings"**
# - In AI: "Process" means computational data processing.
# - In therapy: "Process" means working through emotions.
#
# **The humor**: It humorously personifies an AI as having human emotional problems, despite being literally built on "processing" and "layers." The joke suggests the AI has the same issues as a human in therapy, using technical jargon that coincidentally sounds like therapy jargon.
#
# It's a lighthearted jab at both the "deep" complexity of modern AI systems and the somewhat cliché therapy concept of someone being "complex" with unresolved emotional layers.
