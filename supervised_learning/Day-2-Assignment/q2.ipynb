# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Feature selection
df = pd.read_csv("../../../Downloads/hpp/data.csv")

X = df[['sqft_living', 'bedrooms', 'bathrooms']].values
y = df['price'].values

# %%
# Normalizing the dataset.
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

y = (y - np.mean(y)) / np.std(y)

# %%
# Initialize Parameters
n_samples, n_features = X.shape

weights = np.zeros(n_features)
bias = 0

# %%
# Training
learning_rate = 0.01
epochs = 1000

for i in range(epochs):
    # prediction
    y_pred = np.dot(X, weights) + bias

    # error
    error = y_pred - y

    # gradients
    dw = (1 / n_samples) * np.dot(X.T, error)
    db = (1 / n_samples) * np.sum(error)

    # update
    weights = weights - learning_rate * dw
    bias = bias - learning_rate * db

    # loss
    if i % 100 == 0:
        loss = np.mean(error ** 2)
        print(f"Epoch {i}, Loss: {loss}")
# Out:
# Epoch 0, Loss: 1.0
# Epoch 100, Loss: 0.8376175900284666
# Epoch 200, Loss: 0.8240452283270302
# Epoch 300, Loss: 0.8178405223608166
# Epoch 400, Loss: 0.8145059045755633
# Epoch 500, Loss: 0.8126220163169993
# Epoch 600, Loss: 0.8115196889044131
# Epoch 700, Loss: 0.8108590280546759
# Epoch 800, Loss: 0.8104568458041028
# Epoch 900, Loss: 0.8102095958192836

# %%
y_pred = np.dot(X, weights) + bias

# %%
mse = np.mean((y - y_pred) ** 2)
print("MSE:", mse)
# Out:
# MSE: 0.8100566688465327

# %%
plt.scatter(y, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()
